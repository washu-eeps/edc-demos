# %% [markdown]
# # EDC Demo 01
#
# **Your Name:**
#
# ---
#
# ## Instructions
#
# Work through the cells below. When finished, save this notebook, then commit and push your changes.

# %%
# Setup cell - run this first
import ee
from google.cloud import storage

PROJECT = "eeps-geospatial"
BUCKET = "wustl-eeps-edc"

ee.Initialize(project=PROJECT)
print("Ready!")

# %% [markdown]
# ## Part 1: Your Task Here
#
# Description of what students should do...

# %%
# Your code here
